# %%
import pandas as pd

df1 = pd.read_csv("../Projects/Project2/data/id-hw-exams.csv")
df2 = pd.read_csv("../Projects/Project2/data/id-section.csv")

h = pd.merge(df1, df2, left_on="SID", right_on="NetID", how = 'outer')

h
# Out:
#     First Name  Last Name       SID  Homework 1  Homework 1 - Max Points  \
# 0        Aaron     Lester  axl60952        68.0                     80.0
# 1         Adam     Cooper  amc28428        80.0                     80.0
# 2         Alec      Curry  axc64717        69.0                     80.0
# 3    Alexander  Rodriguez  akr14831        50.0                     80.0
# 4        Amber    Daniels  axd11293        54.0                     80.0
# ..         ...        ...       ...         ...                      ...
# 295        NaN        NaN       NaN         NaN                      NaN
# 296        NaN        NaN       NaN         NaN                      NaN
# 297        NaN        NaN       NaN         NaN                      NaN
# 298        NaN        NaN       NaN         NaN                      NaN
# 299        NaN        NaN       NaN         NaN                      NaN
#
#     Homework 1 - Submission Time  Homework 2  Homework 2 - Max Points  \
# ...
